# %% [markdown]
# <a href="https://colab.research.google.com/github/Galvezcpe/CPE009A/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if 5 > 2:
   print("Five is greater than two")
# Out:
# Five is greater than two

# %%
#This is a comment
print("Hello world")
# Out:
# Hello world

# %%
#This is a comment
print("If 5 > 2")
print("Five is greater than two")
# Out:
# If 5 > 2
# Five is greater than two

# %%
x = 1
a, b = 0,-1
a, b, c = 0, -1, 2

b = "sally" #This is a type of string
b = int(4)
print(b)

b = float (4)
print (b)
# Out:
# 4
# 4.0

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
y = "John"
print (y)
y = 'john'
print (y)
# Out:
# John
# john

# %%
y = "John"
print (y)
print(type(y))
y = 'john'
print (y)
print(type(y))
# Out:
# John
# <class 'str'>
# john
# <class 'str'>

# %%
a = 4
A = "Sally"
#A will not overwrite a

print(A,A)
# Out:
# Sally Sally

# %%
x, y, z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %%
x = y =  z = "four"
print (x)
print (y)
print (z)
# Out:
# four
# four
# four

# %%
x = "very enjoying"
print("Python programming is " + x)
# Out:
# Python programming is very enjoying

# %%
x = "Python is "
y = "enjoying"
z = x + y
print (z)
# Out:
# Python is enjoying

# %%
10 // 3
# Out:
# 3

# %% [markdown]
# Arithmetic Operations

# %%
x = 5
y = 3
print (x + y)
print (x * y)
print (x / y)
print (x % y)
print (x ** y)
print (x // y)

sum = x + y
product = x * y
division = x / y
modulus = x % y
exponentiation = x ** y
# Out:
# 8
# 15
# 1.6666666666666667
# 2
# 125
# 1

# %% [markdown]
# Assignment Operators

# %%
s = 3
s += 3
print(s)
s -= 3
print(s)
s *= 3
print(s)
s /= 3
print (s)
s %= 3
print(s)
s //= 3
print (s)
s **= 3
print(s)
# Out:
# 6
# 3
# 9
# 3.0
# 0.0
# 0.0
# 0.0

# %%
t,u = 1, 2


print(t == u)
print(t!= u)
print(t > u)
print(t < u)
print(t >=u)
# Out:
# False
# True
# False
# True
# False

# %% [markdown]
# Logical Operators

# %%
x = 10
x < 5 and x < 11
# Out:
# False

# %%
x = 10
x < 5 or x < 11
# Out:
# True

# %%
x = 10
not( x < 5 and x < 11)
# Out:
# True

# %%
x is y
# Out:
# False

# %% [markdown]
# Bitwise Operators

# %%
x is not y
# Out:
# True

# %%
v = 2
v << 1
# Out:
# 4

# %%
v = 2
v << 2
# Out:
# 8

# %%
1&2
# Out:
# 0

# %%
15&15
# Out:
# 15
