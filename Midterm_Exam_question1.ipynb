# %% [markdown]
# <a href="https://colab.research.google.com/github/Galvezcpe/CPE009A/blob/main/Midterm_Exam_question1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1
while a < 1:
  print("*", +i)
  if a == 1:
    print("*")

# %%
i = 1
for i in range(1):
  print("*")
  if i in range(2):
    print("**")
    if i in range(3):
      print("***")
      if i in range(4):
        print("****")
        if i in range(5):
          print("*****")
          if i == 5:
           break
          if i in range(4):
            print("****")
            if i in range(3):
              print("***")
              if i in range(2):
                print("**")
                if i in range(1):
                  print("*")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
"({[]})" = True

"([)]" =  False

"((()))" = True

"({)}" = False

# %%
print(input(str))
if input(str) == "({[]})":
  print(True)
else:
  input(str) == "((()))"
  print(True)
  else if input(str) == "([)]"
  print(False)
  else if
input(str) == "({)}"
  print(False)
# Out:
#   File "/tmp/ipykernel_165/4148362251.py", line 7
#     else:
#     ^
# SyntaxError: invalid syntax
