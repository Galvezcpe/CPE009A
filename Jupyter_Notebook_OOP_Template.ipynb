# %% [markdown]
# <a href="https://colab.research.google.com/github/Galvezcpe/CPE009A/blob/main/Jupyter_Notebook_OOP_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Hands-on Activity 2.1 Literals and Variables </h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed: Jan 15, 2026** |
# | **Section: CPE12S2**  | **Date Submitted:** |
# | **Student Name: Nichollo Dave Galvez**  | **Instructor's Name: Engr. Sayo** |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1. Implement literals and variables in a python program.
#
# **Intended Learning Outcome:**
#
# 1.   Write a simple program implementing literals and variables.
# 2.   Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# (Discuss the use of variables, constants and literals in a python program.)
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Supplementary Activity**:
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the procedures here

#Prelim Grade - 50% Prelim Exam + 50% Prelim Class Standing
print("\nPRELIM GRADE")
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)

#Midterm Grade - 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing)
print("\nMIDTERM GRADE")
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("Midterm CS is: ", MCS)
MEX = float(input("Enter Midterm Exam grade: "))
MG = (PG*(1/3)) + (2/3)*(MEX*.5 + MCS*.5)
print("Midterm Grade is: ", "%.2f" % MG)

#Final Grade - 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
print("\nFINAL GRADE")
FHOA = float(input("Enter Hands-on Activity grade: "))
FQIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA*.5 + FQIZ*.3 + FAS*.2
print("Final CS is: ", FCS)
FEX = float(input("Enter Final Exam grade: "))
FG = MG*(1/3) + (2/3)*(FEX*.5 + FCS*.5)
print("Final Grade is: ", "%.2f" % FG)
# Out:
# PRELIM GRADE
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 100
# Enter Prelim Assignment grade: 100
# Prelim CS is:  100.0
# Enter Prelim Exam grade: 100
# Prelim Grade is:  100.00
#
# MIDTERM GRADE
# Enter Hands-on Activity grade: 100
# Enter Midterm Quiz grade: 100
# Enter Midterm Assignment grade: 100
# Midterm CS is:  100.0
# Enter Midterm Exam grade: 100
# Midterm Grade is:  100.00
#
# FINAL GRADE
# Enter Hands-on Activity grade: 100
# Enter Final Quiz grade: 100
# Enter Final Assignment grade: 100
# Final CS is:  100.0
# Enter Final Exam grade: 100
# Final Grade is:  100.00

# %%
# Place all the output of the supplementary activity here

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)

# %%
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)
# Out:
# Enter Hands-on Activity grade: 86
# Enter Prelim Quiz grade: 89
# Enter Prelim Assignment grade: 86
# Prelim CS is:  86.9
# Enter Prelim Exam grade: 78
# Prelim Grade is:  82.45
