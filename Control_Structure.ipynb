# %% [markdown]
# <a href="https://colab.research.google.com/github/Galvezcpe/CPE009A/blob/main/Control_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#If Statements

a=12
b=100
if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
#Elif Statements

a = 12
b = 12
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
#Else Sttements

a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
#Short Hand If Statement

if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %%
#Short Hand If..Else Statement

a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %%
#And-both conditions are true

a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %%
#Or-at least one of the conditons is true

a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %%
#Create a python that will display above 10, ave 20, above 30, above 40
# + 5
x = 41
if x > 10:
  print("Above ten,")
  if x > 20:
    print("above 20,")
    if x > 30:
      print("above 30,")
      if x > 40:
        print("and above 40!")
      else:
        print("but not above 20.")
    else:
      print("but not above 20.")
else:
  print("but not above 20.")
# Out:
# Above ten,
# above 20,
# above 30,
# and above 40!

# %%
#EXAMPLE 1, write a program that determines if the input age is qualify to vote or not.
# +2
print("Age: ")
age = int(input())

if age >= 18:
 print("old enough to vote")
else:
 print("too young to vote")
# Out:
# Age:
# 20
# old enough to vote
