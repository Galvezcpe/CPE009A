# %% [markdown]
# <a href="https://colab.research.google.com/github/Galvezcpe/CPE009A/blob/main/Galvez_Laboratory_Activity_1_Literals%2C_Operators%2C_and_VariablesLaboratory_Activity_1_Literals%2C_Operators%2C_and_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
value = 5
print(value)
# Out:
# 5

# %%
value = 5.0
print(value)
# Out:
# 5.0

# %%
value = 2+3j
print (value)
# Out:
# (2+3j)

# %%
value = 'Hello World'
print (value)
# Out:
# Hello World

# %%
value = "Hello World"
print (value)
# Out:
# Hello World

# %%
value = True
print (value)
# Out:
# True

# %%
value = False
print (value)
# Out:
# False

# %%
value = [1,2,3,4,5]
print (value)
# Out:
# [1, 2, 3, 4, 5]

# %%
value = (1,2,3,4,5)
print (value)
# Out:
# (1, 2, 3, 4, 5)

# %%
value = {'name': 'Your_name'}
print (value)
# Out:
# {'name': 'Your_name'}

# %%
value = None
print (value)
# Out:
# None

# %%
value = 5

# %%
value2 = -6

# %%
value+value2
# Out:
# -1

# %%
value, value2 = 5.0, 6
print (value,value2)
# Out:
# 5.0 6

# %%
value, value2 = 5, 6.1
print (value,value2)
# Out:
# 5 6.1

# %%
value, value2 = "Hello",'world'
print (value,value2)
# Out:
# Hello world

# %%
value, value2 = [1,2,3], [4,5,6]
print (value,value2)
# Out:
# [1, 2, 3] [4, 5, 6]

# %%
value, value2 = {"name":"Royce"}, {"age":2}
print (value,value2)
# Out:
# {'name': 'Royce'} {'age': 2}

# %%
value, value2 = 30, 4
print (value*value2)
# Out:
# 120

# %%
value, value2 = 30, 4
print (value2**2)
# Out:
# 16

# %%
value, value2 = 30, 4
print (value2**3)
# Out:
# 64

# %%
value, value2 = 30, 4
print (value*value2+value2**2+1)
# Out:
# 137

# %%
value, value2 = 30, 4
print (value/value2)
# Out:
# 7.5

# %%
value, value2 = 30, 4
print (value%value2)
# Out:
# 2

# %%
input ("Enter Name ")
# Out:
# Enter Name Ja
# 'Ja'

# %% [markdown]
# Assigning Input Data to a Variable
# # Finding a person’s BMI (metric) **bold text**

# %%
weight = float(weight)
height = float(height)

name = input ("Enter Name ")
weight = input ("Enter Weight (kg): ")
height = input ("Enter Height (m): ")
bmi = float(weight)/float(height)**2

print (name)
print (weight)
print (height)
print (bmi)
# Out:
# Enter Name Jarel
# Enter Weight (kg): 74
# Enter Height (m): 1.6764
# Jarel
# 74
# 1.6764
# 26.331549449141143

# %% [markdown]
# Supplementary Activity:

# %%
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))

area = 1/2 * base * height
print ("The area of the triangle is: ", area )
# Out:
# Enter the base of the triangle: 7
# Enter the height of the triangle: 6
# The area of the triangle is:  21.0

# %%
Celsius = float(input("Enter the temperature in Celsius: "))
Fahrenheit = (Celsius * 9/5) + 32

print ("The temperature in Fahrenheit is: ", Fahrenheit )
# Out:
# Enter the temperature in Celsius: 0
# The temperature in Fahrenheit is:  32.0

# %%
x1 = float(input("Enter the x-coordinate of the first point: "))
y1 = float(input("Enter the y-coordinate of the first point: "))
x2 = float(input("Enter the x-coordinate of the second point: "))
y2 = float(input("Enter the y-coordinate of the second point: "))
distance = ((x2 - x1)**2 + (y2 - y1)**2)**0.5
print ("The distance is: ", distance)
# Out:
# Enter the x-coordinate of the first point: 7
# Enter the y-coordinate of the first point: 95
# Enter the x-coordinate of the second point: 4
# Enter the y-coordinate of the second point: 6
# The distance is:  89.05054744357274
